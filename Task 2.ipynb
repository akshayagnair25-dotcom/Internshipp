# %%
import pandas as pd

df = pd.read_csv("dirty_cafe_sales.csv")
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df['Transaction Date']=pd.to_datetime(df['Transaction Date'],errors = 'coerce')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
df['Payment Method'] = df['Payment Method'].str.lower().str.strip()
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  Takeaway       2023-09-08
# 1               cash  In-store       2023-05-16
# 2        credit card  In-store       2023-07-19
# 3            unknown   UNKNOWN       2023-04-27
# 4     digital wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  digital wallet       NaN       2023-06-02
# 9997  digital wallet       NaN       2023-03-02
# 9998  digital wallet       NaN       2023-12-02
# 9999            cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %%
df = df.dropna(subset=['Total Spent','Payment Method','Location'])
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  Takeaway       2023-09-08
# 1               cash  In-store       2023-05-16
# 2        credit card  In-store       2023-07-19
# 3            unknown   UNKNOWN       2023-04-27
# 4     digital wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9984            cash  Takeaway       2023-07-27
# 9986     credit card  In-store       2023-12-14
# 9991            cash  Takeaway       2023-02-24
# 9992         unknown  In-store       2023-07-05
# 9999            cash  In-store       2023-11-07
#
# [4927 rows x 8 columns]

# %%
df['Payment Method'] = df['Payment Method'].replace({
    'digital wallet':'Digital Wallet',
    'credit card':'Credit Card',
    'cash':'Cash',
    'unknown':'Unknown'
})
df
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16176\330072132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Payment Method'] = df['Payment Method'].replace({
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            Unknown   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9984            Cash  Takeaway       2023-07-27
# 9986     Credit Card  In-store       2023-12-14
# 9991            Cash  Takeaway       2023-02-24
# 9992         Unknown  In-store       2023-07-05
# 9999            Cash  In-store       2023-11-07
#
# [4927 rows x 8 columns]

# %%
df['Total Spent']=pd.to_numeric(df['Total Spent'],errors='coerce')
df
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_16176\815260387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Spent']=pd.to_numeric(df['Total Spent'],errors='coerce')
#      Transaction ID      Item Quantity Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0          4.0
# 1       TXN_4977031      Cake        4            3.0         12.0
# 2       TXN_4271903    Cookie        4            1.0          NaN
# 3       TXN_7034554     Salad        2            5.0         10.0
# 4       TXN_3160411    Coffee        2            2.0          4.0
# ...             ...       ...      ...            ...          ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0          4.0
# 9986    TXN_2858441  Sandwich        2            4.0          8.0
# 9991    TXN_3897619  Sandwich        3            4.0         12.0
# 9992    TXN_2739140  Smoothie        4            4.0         16.0
# 9999    TXN_6170729  Sandwich        3            4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            Unknown   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9984            Cash  Takeaway       2023-07-27
# 9986     Credit Card  In-store       2023-12-14
# 9991            Cash  Takeaway       2023-02-24
# 9992         Unknown  In-store       2023-07-05
# 9999            Cash  In-store       2023-11-07
#
# [4927 rows x 8 columns]

# %%
df = df[df['Total Spent']>0]
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0          4.0
# 1       TXN_4977031      Cake        4            3.0         12.0
# 3       TXN_7034554     Salad        2            5.0         10.0
# 4       TXN_3160411    Coffee        2            2.0          4.0
# 6       TXN_4433211   UNKNOWN        3            3.0          9.0
# ...             ...       ...      ...            ...          ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0          4.0
# 9986    TXN_2858441  Sandwich        2            4.0          8.0
# 9991    TXN_3897619  Sandwich        3            4.0         12.0
# 9992    TXN_2739140  Smoothie        4            4.0         16.0
# 9999    TXN_6170729  Sandwich        3            4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 3            Unknown   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# 6              error  Takeaway       2023-10-06
# ...              ...       ...              ...
# 9984            Cash  Takeaway       2023-07-27
# 9986     Credit Card  In-store       2023-12-14
# 9991            Cash  Takeaway       2023-02-24
# 9992         Unknown  In-store       2023-07-05
# 9999            Cash  In-store       2023-11-07
#
# [4762 rows x 8 columns]

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0          4.0
# 1       TXN_4977031      Cake        4            3.0         12.0
# 2       TXN_7034554     Salad        2            5.0         10.0
# 3       TXN_3160411    Coffee        2            2.0          4.0
# 4       TXN_4433211   UNKNOWN        3            3.0          9.0
# ...             ...       ...      ...            ...          ...
# 4757    TXN_3142496  Smoothie  UNKNOWN            4.0          4.0
# 4758    TXN_2858441  Sandwich        2            4.0          8.0
# 4759    TXN_3897619  Sandwich        3            4.0         12.0
# 4760    TXN_2739140  Smoothie        4            4.0         16.0
# 4761    TXN_6170729  Sandwich        3            4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2            Unknown   UNKNOWN       2023-04-27
# 3     Digital Wallet  In-store       2023-06-11
# 4              error  Takeaway       2023-10-06
# ...              ...       ...              ...
# 4757            Cash  Takeaway       2023-07-27
# 4758     Credit Card  In-store       2023-12-14
# 4759            Cash  Takeaway       2023-02-24
# 4760         Unknown  In-store       2023-07-05
# 4761            Cash  In-store       2023-11-07
#
# [4762 rows x 8 columns]
